# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from mlxtend.classifier import StackingClassifier

from sklearn.pipeline import make_pipeline

from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import make_scorer

from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectKBest, SelectPercentile, chi2, f_classif
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import RFECV

# %% [markdown]
# ### 1. Download the dataset(s) for your project. If a train set and a test set are not already available, randomly split the dataset into a train and a test set using stratified sampling so that 80% of the samples go to train set and 20% to test set.

# %%
data = pd.read_csv("datatraining.csv")

y = data['Occupancy']
X = data.loc[:, data.columns != 'Occupancy']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, stratify=y, random_state=42)

# %% [markdown]
# ### 2. Randomly split your train set into a validation and a new train set (called train set 2) such that the validation set contains 1/5 of the samples in original train set and the train set 2 contains the remaining. Use stratified sampling to assign features to train set 2 and validation set. This should ensure that your validation set contains samples from both classes (i.e. ciliary and non-ciliary with equal proportions)
#
# ![image.png](attachment:image.png)

# %%
X_train_two, X_validation, y_train_two, y_validation = train_test_split(X_train, y_train, test_size=0.20, 
                                                                        stratify=y_train,random_state=42)

# %% [markdown]
# ### 3. Normalize features in your train set 2 and validation set using min-max scaling to interval [0,1]. For this purpose you can first normalize features in your train set 2 and use the same scaling coefficients to normalize validation set. Save the normalized versions as separate files. Repeat normalizing your original train set and use the same normalization coefficients to normalize the two test sets.

# %%
scaler = MinMaxScaler()

scaler.fit(X_train_two)
normalized_x_train_two = scaler.transform(X_train_two)
normalized_x_validation = scaler.transform(X_validation)

np.savetxt("normalized_x_train_two.csv", normalized_x_train_two, delimiter=",")
np.savetxt("normalized_x_validation.csv", normalized_x_validation, delimiter=",")

scaler.fit(normalized_x_train_two)
normalized_x_train = scaler.transform(X_train)
normalized_x_test = scaler.transform(X_test)
normalized_x_validation_with_orig = scaler.transform(X_validation)

# %% [markdown]
# ### 4. Perform a 10-fold cross-validation experiment for the random forest classifier on normalized and unnormalized versions of train set 2. You can set the number of trees to 100. Do you get better accuracy when you perform data normalization?

# %%
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train_two, y_train_two)

unnormalized_accuracy = clf.score(X_validation, y_validation)

clf.fit(normalized_x_train_two, y_train_two)
normalized_accuracy = clf.score(normalized_x_validation, y_validation)

if unnormalized_accuracy > normalized_accuracy or unnormalized_accuracy == normalized_accuracy:
    print("No, I did not. Unnormalized Accuracy: {}, Normalized Accuracy: {}"
          .format(unnormalized_accuracy,normalized_accuracy))
else:
    print("Yes, I did. Unnormalized Accuracy: {}, Normalized Accuracy: {}"
          .format(unnormalized_accuracy,normalized_accuracy))
# Out:
# Yes, I did. Unnormalized Accuracy: 0.992325402916, Normalized Accuracy: 0.993092862625

# %% [markdown]
# ### 5. Perform a 10-fold cross-validation experiment on train set 2 that corresponds to the best performing normalization strategy (i.e. normalized or unnormalized) for the following classifiers:
#
# Logistic regression
#
# k-nearest neighbor (with k=1)
#
# Naïve Bayes
#
# Decision tree
#
# Random forest (number of trees=100)
#
# SVM (RBF kernel C=1.0 gamma=0.125)
#
# RBF network (number of clusters = 3)
#
# Adaboost (number of iterations=10)
#
# You can use default values for other hyper-parameters of the classifiers
# Report the following accuracy measures for each of these classifiers: overall
# accuracy, F-measure, sensitivity, specificity, precision, area under the ROC curve,
# area under the precision recall curve, MCC scores. These will be cross-validation
# accuracies.

# %%
models = [
    ("Logistic Regression",LogisticRegression()),
    ("K-Nearest Neighbour",KNeighborsClassifier(n_neighbors=1)),
    ("Naive Bayes",GaussianNB()),
    ("Decision Tree",DecisionTreeClassifier()),
    ("Random Forest",RandomForestClassifier(n_estimators=100, random_state=42)),
    ("Support Vector Machine",SVC(kernel="rbf", C=1,gamma=0.125)),
    #("RBF Network", RBFNetwork()),
    ("AdaBoostClassifier",AdaBoostClassifier(n_estimators=10))
]

metrics = [
    ("Accuracy Score", accuracy_score),
    ("F-Measure", f1_score),
    ("Sensitivity", recall_score),
    #("Specificity", recall_score),
    ("Precision", precision_score),
    ("Area Under ROC Curve", roc_auc_score),
    #("Area Under Precision Recall Curve", precision_recall_curve),
    ("MCC", matthews_corrcoef)
]

def dump_metrics(features, label, name, model):
    accuracy = 0.0
    
    for metric_name, metric in metrics:
        kfold = KFold(n_splits=10, random_state=42)
        scorer = make_scorer(metric)

        cv_result = cross_val_score(model,features,label.values.ravel(), cv = kfold,scoring = scorer)
        
        if metric_name == "Accuracy Score":
            accuracy = cv_result

        print("{} {}: {}".format(name, metric_name, cv_result.mean()))
    print("")
    
    return accuracy.mean()

print("Unnormalized Results:\n")
for name,model in models:
    dump_metrics(X_train_two, y_train_two, name, model)

print("\nNormalized Results:\n")
for name,model in models:
    dump_metrics(normalized_x_train_two, y_train_two, name, model)
# Out:
# Unnormalized Results:
#
# Logistic Regression Accuracy Score: 0.989444848913
# Logistic Regression F-Measure: 0.975770610521
# Logistic Regression Sensitivity: 0.996503730022
# Logistic Regression Precision: 0.956043827593
# Logistic Regression Area Under ROC Curve: 0.99203463113
# Logistic Regression MCC: 0.969429757352
#
# K-Nearest Neighbour Accuracy Score: 0.990597215787
# K-Nearest Neighbour F-Measure: 0.977935073672
# K-Nearest Neighbour Sensitivity: 0.978283772337
# K-Nearest Neighbour Precision: 0.977935585656
# K-Nearest Neighbour Area Under ROC Curve: 0.986085917877
# K-Nearest Neighbour MCC: 0.972097052435
#
# Naive Bayes Accuracy Score: 0.977164456799
# Naive Bayes F-Measure: 0.948870002332
# Naive Bayes Sensitivity: 0.996503730022
# Naive Bayes Precision: 0.905800044975
# Naive Bayes Area Under ROC Curve: 0.984238121356
# Naive Bayes MCC: 0.936060931094
#
# Decision Tree Accuracy Score: 0.990021400049
# Decision Tree F-Measure: 0.978509046561
# Decision Tree Sensitivity: 0.980137499286
# Decision Tree Precision: 0.979808940785
# Decision Tree Area Under ROC Curve: 0.987414554236
# Decision Tree MCC: 0.972758813089
#
# Random Forest Accuracy Score: 0.992900846442
# Random Forest F-Measure: 0.983412376573
# Random Forest Sensitivity: 0.985472594653
# Random Forest Precision: 0.981539253711
# Random Forest Area Under ROC Curve: 0.990170353351
# Random Forest MCC: 0.97896937675
#
# Support Vector Machine Accuracy Score: 0.952982769652
# Support Vector Machine F-Measure: 0.899961787431
# Support Vector Machine Sensitivity: 0.995470675075
# Support Vector Machine Precision: 0.82173862453
# Support Vector Machine Area Under ROC Curve: 0.968501535111
# Support Vector Machine MCC: 0.876716837187
#
# AdaBoostClassifier Accuracy Score: 0.98982909377
# AdaBoostClassifier F-Measure: 0.97651723707
# AdaBoostClassifier Sensitivity: 0.990126199218
# AdaBoostClassifier Precision: 0.96339109771
# AdaBoostClassifier Area Under ROC Curve: 0.989937837532
# AdaBoostClassifier MCC: 0.970218311322
#
#
# Normalized Results:
#
# Logistic Regression Accuracy Score: 0.988293585133
# Logistic Regression F-Measure: 0.973144990273
# Logistic Regression Sensitivity: 0.991322632384
# Logistic Regression Precision: 0.955805754597
# Logistic Regression Area Under ROC Curve: 0.989444082311
# Logistic Regression MCC: 0.965995739993
#
# K-Nearest Neighbour Accuracy Score: 0.994243313404
# K-Nearest Neighbour F-Measure: 0.986552033323
# K-Nearest Neighbour Sensitivity: 0.984768838674
# K-Nearest Neighbour Precision: 0.98846118903
# K-Nearest Neighbour Area Under ROC Curve: 0.990794299567
# K-Nearest Neighbour MCC: 0.982938956286
#
# Naive Bayes Accuracy Score: 0.978507659158
# Naive Bayes F-Measure: 0.951723504859
# Naive Bayes Sensitivity: 0.996503730022
# Naive Bayes Precision: 0.910997673291
# Naive Bayes Area Under ROC Curve: 0.985091342045
# Naive Bayes MCC: 0.939576207055
#
# Decision Tree Accuracy Score: 0.989829829167
# Decision Tree F-Measure: 0.978532120047
# Decision Tree Sensitivity: 0.979255839409
# Decision Tree Precision: 0.979906110966
# Decision Tree Area Under ROC Curve: 0.987881471717
# Decision Tree MCC: 0.973391457877
#
# Random Forest Accuracy Score: 0.992900846442
# Random Forest F-Measure: 0.983450479581
# Random Forest Sensitivity: 0.985472594653
# Random Forest Precision: 0.981621779461
# Random Forest Area Under ROC Curve: 0.990167363922
# Random Forest MCC: 0.979007192034
#
# Support Vector Machine Accuracy Score: 0.988869033174
# Support Vector Machine F-Measure: 0.974437773273
# Support Vector Machine Sensitivity: 0.997421161214
# Support Vector Machine Precision: 0.952668334902
# Support Vector Machine Area Under ROC Curve: 0.992010150727
# Support Vector Machine MCC: 0.967813632993
#
# AdaBoostClassifier Accuracy Score: 0.98982909377
# AdaBoostClassifier F-Measure: 0.97651723707
# AdaBoostClassifier Sensitivity: 0.990126199218
# AdaBoostClassifier Precision: 0.96339109771
# AdaBoostClassifier Area Under ROC Curve: 0.989937837532
# AdaBoostClassifier MCC: 0.970218311322

# %% [markdown]
# ### 6. Use three feature selection methods to select feature subsets on train set 2 and compute accuracy measures in step 5 for all the classifiers. Repeat for normalized version of train set 2. Do you get improvement in accuracy when you perform feature selection or is it better to use all of the features? Which feature selection strategy gives the best accuracy?

# %%
selectors = []

selectors.append(("VarianceThreshold Selector", VarianceThreshold(threshold=0.6))) # first selector
selectors.append(("SelectKBest", SelectKBest(k=2))) # second selector

for name,selector in selectors:    
    selected_x_train_two = selector.fit_transform(X_train_two, y=y_train_two)
    
    selected_normalized_x_train_two  = scaler.fit_transform(selected_x_train_two)

    print("{} unnormalized results:\n".format(name))
    for name, model in models:
        dump_metrics(selected_x_train_two, y_train_two, name, model)

    print("{} normalized results:\n".format(name))
    for name, model in models:
        dump_metrics(selected_normalized_x_train_two, y_train_two, name, model)
    
lsvc = LinearSVC(C=0.01, penalty="l1", dual=False).fit(X_train_two, y_train_two)
model = SelectFromModel(lsvc, prefit=True) # third selector
selected_x_train_two = model.transform(X_train_two)

selected_normalized_x_train_two  = scaler.fit_transform(selected_x_train_two)

print("SelectFromModel unnormalized results:\n")
for name, model in models:
    dump_metrics(selected_x_train_two, y_train_two, name, model)

print("SelectFromModel normalized results:\n")
for name, model in models:
    dump_metrics(selected_normalized_x_train_two, y_train_two, name, model)
# Out:
# VarianceThreshold Selector unnormalized results:
#
# Logistic Regression Accuracy Score: 0.989444848913
# Logistic Regression F-Measure: 0.975770610521
# Logistic Regression Sensitivity: 0.996503730022
# Logistic Regression Precision: 0.956043827593
# Logistic Regression Area Under ROC Curve: 0.99203463113
# Logistic Regression MCC: 0.969429757352
#
# K-Nearest Neighbour Accuracy Score: 0.990597215787
# K-Nearest Neighbour F-Measure: 0.977935073672
# K-Nearest Neighbour Sensitivity: 0.978283772337
# K-Nearest Neighbour Precision: 0.977935585656
# K-Nearest Neighbour Area Under ROC Curve: 0.986085917877
# K-Nearest Neighbour MCC: 0.972097052435
#
# Naive Bayes Accuracy Score: 0.977164456799
# Naive Bayes F-Measure: 0.948870002332
# Naive Bayes Sensitivity: 0.996503730022
# Naive Bayes Precision: 0.905800044975
# Naive Bayes Area Under ROC Curve: 0.984238121356
# Naive Bayes MCC: 0.936060931094
#
# Decision Tree Accuracy Score: 0.990789154367
# Decision Tree F-Measure: 0.977181337926
# Decision Tree Sensitivity: 0.980009622091
# Decision Tree Precision: 0.979927694193
# Decision Tree Area Under ROC Curve: 0.986952674645
# Decision Tree MCC: 0.972194083198
#
# Random Forest Accuracy Score: 0.993284355903
# Random Forest F-Measure: 0.984347940074
# Random Forest Sensitivity: 0.987189364473
# Random Forest Precision: 0.981730782894
# Random Forest Area Under ROC Curve: 0.991023937675
# Random Forest MCC: 0.980161585539
#
# Support Vector Machine Accuracy Score: 0.952982769652
# Support Vector Machine F-Measure: 0.899961787431
# Support Vector Machine Sensitivity: 0.995470675075
# Support Vector Machine Precision: 0.82173862453
# Support Vector Machine Area Under ROC Curve: 0.968501535111
# Support Vector Machine MCC: 0.876716837187
#
# AdaBoostClassifier Accuracy Score: 0.989637155191
# AdaBoostClassifier F-Measure: 0.976070402469
# AdaBoostClassifier Sensitivity: 0.989271498364
# AdaBoostClassifier Precision: 0.963399737458
# AdaBoostClassifier Area Under ROC Curve: 0.989512890258
# AdaBoostClassifier MCC: 0.969669060856
#
# AdaBoostClassifier normalized results:
#
# Logistic Regression Accuracy Score: 0.988293585133
# Logistic Regression F-Measure: 0.973144990273
# Logistic Regression Sensitivity: 0.991322632384
# Logistic Regression Precision: 0.955805754597
# Logistic Regression Area Under ROC Curve: 0.989444082311
# Logistic Regression MCC: 0.965995739993
#
# K-Nearest Neighbour Accuracy Score: 0.993859436245
# K-Nearest Neighbour F-Measure: 0.98571521875
# K-Nearest Neighbour Sensitivity: 0.984768838674
# K-Nearest Neighbour Precision: 0.986799048281
# K-Nearest Neighbour Area Under ROC Curve: 0.990546774814
# K-Nearest Neighbour MCC: 0.981858185208
#
# Naive Bayes Accuracy Score: 0.977164456799
# Naive Bayes F-Measure: 0.948870002332
# Naive Bayes Sensitivity: 0.996503730022
# Naive Bayes Precision: 0.905800044975
# Naive Bayes Area Under ROC Curve: 0.984238121356
# Naive Bayes MCC: 0.936060931094
#
# Decision Tree Accuracy Score: 0.990980725248
# Decision Tree F-Measure: 0.978549070755
# Decision Tree Sensitivity: 0.979920926719
# Decision Tree Precision: 0.978342264782
# Decision Tree Area Under ROC Curve: 0.986377538693
# Decision Tree MCC: 0.972221283419
#
# Random Forest Accuracy Score: 0.993475926784
# Random Forest F-Measure: 0.984784359037
# Random Forest Sensitivity: 0.987189364473
# Random Forest Precision: 0.982607552521
# Random Forest Area Under ROC Curve: 0.991145888895
# Random Forest MCC: 0.980722293489
#
# Support Vector Machine Accuracy Score: 0.988869033174
# Support Vector Machine F-Measure: 0.974437773273
# Support Vector Machine Sensitivity: 0.997421161214
# Support Vector Machine Precision: 0.952668334902
# Support Vector Machine Area Under ROC Curve: 0.992010150727
# Support Vector Machine MCC: 0.967813632993
#
# AdaBoostClassifier Accuracy Score: 0.989637155191
# AdaBoostClassifier F-Measure: 0.976070402469
# AdaBoostClassifier Sensitivity: 0.989271498364
# AdaBoostClassifier Precision: 0.963399737458
# AdaBoostClassifier Area Under ROC Curve: 0.989512890258
# AdaBoostClassifier MCC: 0.969669060856
#
# SelectKBest unnormalized results:
#
# Logistic Regression Accuracy Score: 0.989444848913
# Logistic Regression F-Measure: 0.975770610521
# Logistic Regression Sensitivity: 0.996503730022
# Logistic Regression Precision: 0.956043827593
# Logistic Regression Area Under ROC Curve: 0.99203463113
# Logistic Regression MCC: 0.969429757352
#
# K-Nearest Neighbour Accuracy Score: 0.989062442547
# K-Nearest Neighbour F-Measure: 0.974325691464
# K-Nearest Neighbour Sensitivity: 0.972994900796
# K-Nearest Neighbour Precision: 0.97599234349
# K-Nearest Neighbour Area Under ROC Curve: 0.983197815654
# K-Nearest Neighbour MCC: 0.967505439107
#
# Naive Bayes Accuracy Score: 0.980810554416
# Naive Bayes F-Measure: 0.956691961578
# Naive Bayes Sensitivity: 0.996503730022
# Naive Bayes Precision: 0.920231419054
# Naive Bayes Area Under ROC Curve: 0.986557412478
# Naive Bayes MCC: 0.945746474869
#
# Decision Tree Accuracy Score: 0.986759179591
# Decision Tree F-Measure: 0.968369652143
# Decision Tree Sensitivity: 0.964546841784
# Decision Tree Precision: 0.971444492534
# Decision Tree Area Under ROC Curve: 0.979282410683
# Decision Tree MCC: 0.961609054158
#
# Random Forest Accuracy Score: 0.990213706327
# Random Forest F-Measure: 0.977148880705
# Random Forest Sensitivity: 0.985522679049
# Random Forest Precision: 0.96905196115
# Random Forest Area Under ROC Curve: 0.98849534906
# Random Forest MCC: 0.971029261754
#
# Support Vector Machine Accuracy Score: 0.95144836411
# Support Vector Machine F-Measure: 0.896754726882
# Support Vector Machine Sensitivity: 0.99189950965
# Support Vector Machine Precision: 0.81882575048
# Support Vector Machine Area Under ROC Curve: 0.966225847129
# Support Vector Machine MCC: 0.872475033702
#
# AdaBoostClassifier Accuracy Score: 0.988869400872
# AdaBoostClassifier F-Measure: 0.974171749893
# AdaBoostClassifier Sensitivity: 0.988409429398
# AdaBoostClassifier Precision: 0.960495333524
# AdaBoostClassifier Area Under ROC Curve: 0.98872684589
# AdaBoostClassifier MCC: 0.96730011486
#
# AdaBoostClassifier normalized results:
#
# Logistic Regression Accuracy Score: 0.988677094594
# Logistic Regression F-Measure: 0.97372340897
# Logistic Regression Sensitivity: 0.990828538067
# Logistic Regression Precision: 0.957340670116
# Logistic Regression Area Under ROC Curve: 0.989443335025
# Logistic Regression MCC: 0.966796658933
#
# K-Nearest Neighbour Accuracy Score: 0.989254013428
# K-Nearest Neighbour F-Measure: 0.974799069203
# K-Nearest Neighbour Sensitivity: 0.973887757939
# K-Nearest Neighbour Precision: 0.976001160277
# K-Nearest Neighbour Area Under ROC Curve: 0.983644244225
# K-Nearest Neighbour MCC: 0.968080820223
#
# Naive Bayes Accuracy Score: 0.980810554416
# Naive Bayes F-Measure: 0.956691961578
# Naive Bayes Sensitivity: 0.996503730022
# Naive Bayes Precision: 0.920231419054
# Naive Bayes Area Under ROC Curve: 0.986557412478
# Naive Bayes MCC: 0.945746474869
#
# Decision Tree Accuracy Score: 0.986182996154
# Decision Tree F-Measure: 0.968320443515
# Decision Tree Sensitivity: 0.965502429265
# Decision Tree Precision: 0.970525497007
# Decision Tree Area Under ROC Curve: 0.980040611523
# Decision Tree MCC: 0.962785603731
#
# Random Forest Accuracy Score: 0.990213706327
# Random Forest F-Measure: 0.977148880705
# Random Forest Sensitivity: 0.985522679049
# Random Forest Precision: 0.96905196115
# Random Forest Area Under ROC Curve: 0.98849534906
# Random Forest MCC: 0.971029261754
#
# Support Vector Machine Accuracy Score: 0.982921511093
# Support Vector Machine F-Measure: 0.961296905033
# Support Vector Machine Sensitivity: 0.996503730022
# Support Vector Machine Precision: 0.928774261902
# Support Vector Machine Area Under ROC Curve: 0.987895506776
# Support Vector Machine MCC: 0.951441710045
#
# AdaBoostClassifier Accuracy Score: 0.988869400872
# AdaBoostClassifier F-Measure: 0.974171749893
# AdaBoostClassifier Sensitivity: 0.988409429398
# AdaBoostClassifier Precision: 0.960495333524
# AdaBoostClassifier Area Under ROC Curve: 0.98872684589
# AdaBoostClassifier MCC: 0.96730011486
#
# SelectFromModel unnormalized results:
#
# Logistic Regression Accuracy Score: 0.989444848913
# Logistic Regression F-Measure: 0.975770610521
# Logistic Regression Sensitivity: 0.996503730022
# Logistic Regression Precision: 0.956043827593
# Logistic Regression Area Under ROC Curve: 0.99203463113
# Logistic Regression MCC: 0.969429757352
#
# K-Nearest Neighbour Accuracy Score: 0.990597215787
# K-Nearest Neighbour F-Measure: 0.977935073672
# K-Nearest Neighbour Sensitivity: 0.978283772337
# K-Nearest Neighbour Precision: 0.977935585656
# K-Nearest Neighbour Area Under ROC Curve: 0.986085917877
# K-Nearest Neighbour MCC: 0.972097052435
#
# Naive Bayes Accuracy Score: 0.977164456799
# Naive Bayes F-Measure: 0.948870002332
# Naive Bayes Sensitivity: 0.996503730022
# Naive Bayes Precision: 0.905800044975
# Naive Bayes Area Under ROC Curve: 0.984238121356
# Naive Bayes MCC: 0.936060931094
#
# Decision Tree Accuracy Score: 0.990981092947
# Decision Tree F-Measure: 0.977584766416
# Decision Tree Sensitivity: 0.980933004264
# Decision Tree Precision: 0.980062075178
# Decision Tree Area Under ROC Curve: 0.987359380393
# Decision Tree MCC: 0.972107678887
#
# Random Forest Accuracy Score: 0.993284355903
# Random Forest F-Measure: 0.984347940074
# Random Forest Sensitivity: 0.987189364473
# Random Forest Precision: 0.981730782894
# Random Forest Area Under ROC Curve: 0.991023937675
# Random Forest MCC: 0.980161585539
#
# Support Vector Machine Accuracy Score: 0.952982769652
# Support Vector Machine F-Measure: 0.899961787431
# Support Vector Machine Sensitivity: 0.995470675075
# Support Vector Machine Precision: 0.82173862453
# Support Vector Machine Area Under ROC Curve: 0.968501535111
# Support Vector Machine MCC: 0.876716837187
#
# AdaBoostClassifier Accuracy Score: 0.989637155191
# AdaBoostClassifier F-Measure: 0.976070402469
# AdaBoostClassifier Sensitivity: 0.989271498364
# AdaBoostClassifier Precision: 0.963399737458
# AdaBoostClassifier Area Under ROC Curve: 0.989512890258
# AdaBoostClassifier MCC: 0.969669060856
#
# SelectFromModel normalized results:
#
# Logistic Regression Accuracy Score: 0.988293585133
# Logistic Regression F-Measure: 0.973144990273
# Logistic Regression Sensitivity: 0.991322632384
# Logistic Regression Precision: 0.955805754597
# Logistic Regression Area Under ROC Curve: 0.989444082311
# Logistic Regression MCC: 0.965995739993
#
# K-Nearest Neighbour Accuracy Score: 0.993859436245
# K-Nearest Neighbour F-Measure: 0.98571521875
# K-Nearest Neighbour Sensitivity: 0.984768838674
# K-Nearest Neighbour Precision: 0.986799048281
# K-Nearest Neighbour Area Under ROC Curve: 0.990546774814
# K-Nearest Neighbour MCC: 0.981858185208
#
# Naive Bayes Accuracy Score: 0.977164456799
# Naive Bayes F-Measure: 0.948870002332
# Naive Bayes Sensitivity: 0.996503730022
# Naive Bayes Precision: 0.905800044975
# Naive Bayes Area Under ROC Curve: 0.984238121356
# Naive Bayes MCC: 0.936060931094
#
# Decision Tree Accuracy Score: 0.990597215787
# Decision Tree F-Measure: 0.977600399062
# Decision Tree Sensitivity: 0.978131646425
# Decision Tree Precision: 0.979944575326
# Decision Tree Area Under ROC Curve: 0.985452808265
# Decision Tree MCC: 0.972793711015
#
# Random Forest Accuracy Score: 0.993475926784
# Random Forest F-Measure: 0.984784359037
# Random Forest Sensitivity: 0.987189364473
# Random Forest Precision: 0.982607552521
# Random Forest Area Under ROC Curve: 0.991145888895
# Random Forest MCC: 0.980722293489
#
# Support Vector Machine Accuracy Score: 0.988869033174
# Support Vector Machine F-Measure: 0.974437773273
# Support Vector Machine Sensitivity: 0.997421161214
# Support Vector Machine Precision: 0.952668334902
# Support Vector Machine Area Under ROC Curve: 0.992010150727
# Support Vector Machine MCC: 0.967813632993
#
# AdaBoostClassifier Accuracy Score: 0.989637155191
# AdaBoostClassifier F-Measure: 0.976070402469
# AdaBoostClassifier Sensitivity: 0.989271498364
# AdaBoostClassifier Precision: 0.963399737458
# AdaBoostClassifier Area Under ROC Curve: 0.989512890258
# AdaBoostClassifier MCC: 0.969669060856

# %% [markdown]
# ### 7. Choose the version of train set 2 that contains the optimum feature set you found in step 6 and the data for the best normalization strategy. Optimize the following hyperparameters:
#
# k parameter in k-NN
# number of trees in random forest
# Number of clusters in RBF network
# Number of iterations in Adaboost
# C, gamma parameter in SVM
#
# Try a grid of values and choose the best value(s) that maximize the overall cross validation accuracy.
#
# •For k-NN you can choose 1 5 10 15 ... 100 (with increments of 5 after k=5)
# •For number of trees in random forest you can try 5 10 25 50 75 100 150 200 250 300 350 400 450 500
# •For number of clusters in RBF network you can try: 2 3 4 5 6 7 8 9 10 15 20 25 30 35 40 45 50
# •For the number of iterations in Adaboost you can try 5 10 15 20 25 30 40 50 75 100 125 150 175 200
#
# To optimize C and gamma parameters of the SVM you can consider the
# following parameter grid:
#
# C ∈ {2^-5, 2^-3, 2^-1, 2^1, 2^3, 2^5, ... 2^13, 2^15}
# γ ∈ {2^-15, 2^-13, ... , 2^-1, 2^1, 2^3, 2^5}
#
# There are a total of 11 values for the C parameter and 11 values for the gamma parameter (a total of 121 values to consider for the (C, gamma) pair).
#
# Report the best cross-validation accuracies and optimum parameter values you found.
#
# Compute predictions on the validation set using the models trained by optimum
# hyper-parameters. Report the same accuracy measures as in step 5.

# %%
name, selector = selectors[0]

optimum_x_train_two = selector.fit_transform(X_train_two, y=y_train_two)
optimum_normalized_x_train_two  = scaler.fit_transform(optimum_x_train_two)

hyper_parameters = {
    "K-Nearest Neighbour": [1] + [i*5 for i in range(1,21)],
    "Random Forest": [5,10,25,50,75,100,150,200,250,300,350,400,450,500],
    #"RBF Network": [2,3,4,5,6,7,8,9,10,15,20,25,30,35,40,45,50]),
    "AdaBoostClassifier": [5,10,15,20,25,30,40,50,75,100,125,150,175,200],
    "Support Vector Machine": ([2**i for i in range(-5,16,2)], [2**i for i in range(-15,6,2)])
}

opt_param_k_nearest,opt_param_random_forest,opt_param_svm,opt_param_ada = 0,0,0,0

for model_name, parameters in hyper_parameters.iteritems():
    model = None
    optimum_accuracy = 0.0
    optimum_parameters = ""
    
    if model_name == "K-Nearest Neighbour":
        for parameter in parameters:
            print("n_neighbors: {}".format(parameter))
            model = KNeighborsClassifier(n_neighbors=parameter)
            accuracy = dump_metrics(optimum_normalized_x_train_two, y_train_two, model_name, model)
            
            if accuracy > optimum_accuracy:
                optimum_accuracy = accuracy
                optimum_parameters = "n_neighbors=" + str(parameter)
    elif model_name == "Random Forest":
        for parameter in parameters:
            print("n_estimators: {}".format(parameter))
            model = RandomForestClassifier(n_estimators=parameter)
            accuracy = dump_metrics(optimum_normalized_x_train_two, y_train_two, model_name, model)
            
            if accuracy > optimum_accuracy:
                optimum_accuracy = accuracy
                optimum_parameters = "n_estimators=" + str(parameter)
    elif model_name == "Support Vector Machine":
        C_values = parameters[0]
        gamma_values = parameters[1]
        
        for C in C_values:
            for gamma in gamma_values:
                print("C: {}, gamma: {}".format(C, gamma))
                model = SVC(kernel="rbf", C=C,gamma=gamma)
                accuracy = dump_metrics(optimum_normalized_x_train_two, y_train_two, model_name, model)
                
                if accuracy > optimum_accuracy:
                    optimum_accuracy = accuracy
                    optimum_parameters = "C:" + str(C) + ", " + "gamma:" + str(gamma)
    elif model_name == "AdaBoostClassifier":
        for parameter in parameters:
            print("n_estimators: {}".format(parameter))
            model = AdaBoostClassifier(n_estimators=parameter)
            accuracy = dump_metrics(optimum_normalized_x_train_two, y_train_two, model_name, model)
            
            if accuracy > optimum_accuracy:
                optimum_accuracy = accuracy
                optimum_parameters = "n_estimators=" + str(parameter)
    
    print("Optimum Accuracy for {}: {}".format(model_name, optimum_accuracy))
    print("Optimum Parameters:")
    print(optimum_parameters + "\n\n")
# Out:
# n_estimators: 5
# AdaBoostClassifier Accuracy Score: 0.988869033174
# AdaBoostClassifier F-Measure: 0.974168295796
# AdaBoostClassifier Sensitivity: 0.987554728543
# AdaBoostClassifier Precision: 0.961279917036
# AdaBoostClassifier Area Under ROC Curve: 0.988421446682
# AdaBoostClassifier MCC: 0.967270189066
#
# n_estimators: 10
# AdaBoostClassifier Accuracy Score: 0.989637155191
# AdaBoostClassifier F-Measure: 0.976070402469
# AdaBoostClassifier Sensitivity: 0.989271498364
# AdaBoostClassifier Precision: 0.963399737458
# AdaBoostClassifier Area Under ROC Curve: 0.989512890258
# AdaBoostClassifier MCC: 0.969669060856
#
# n_estimators: 15
# AdaBoostClassifier Accuracy Score: 0.989828726072
# AdaBoostClassifier F-Measure: 0.976393169621
# AdaBoostClassifier Sensitivity: 0.985684120989
# AdaBoostClassifier Precision: 0.967568482574
# AdaBoostClassifier Area Under ROC Curve: 0.988331953002
# AdaBoostClassifier MCC: 0.970096102722
#
# n_estimators: 20
# AdaBoostClassifier Accuracy Score: 0.990788786669
# AdaBoostClassifier F-Measure: 0.978646144092
# AdaBoostClassifier Sensitivity: 0.984621695901
# AdaBoostClassifier Precision: 0.972856020429
# AdaBoostClassifier Area Under ROC Curve: 0.98852018784
# AdaBoostClassifier MCC: 0.972844279266
#
# n_estimators: 25
# AdaBoostClassifier Accuracy Score: 0.990788786669
# AdaBoostClassifier F-Measure: 0.978697265701
# AdaBoostClassifier Sensitivity: 0.98648252332
# AdaBoostClassifier Precision: 0.971314013437
# AdaBoostClassifier Area Under ROC Curve: 0.989208479708
# AdaBoostClassifier MCC: 0.97298149576
#
# n_estimators: 30
# AdaBoostClassifier Accuracy Score: 0.991556540987
# AdaBoostClassifier F-Measure: 0.980427502854
# AdaBoostClassifier Sensitivity: 0.988191925029
# AdaBoostClassifier Precision: 0.973050180569
# AdaBoostClassifier Area Under ROC Curve: 0.990307996576
# AdaBoostClassifier MCC: 0.97519966632
#
# n_estimators: 40
# AdaBoostClassifier Accuracy Score: 0.991748479567
# AdaBoostClassifier F-Measure: 0.980862863437
# AdaBoostClassifier Sensitivity: 0.988191925029
# AdaBoostClassifier Precision: 0.973834054775
# AdaBoostClassifier Area Under ROC Curve: 0.990430881657
# AdaBoostClassifier MCC: 0.975721382104
#
# n_estimators: 50
# AdaBoostClassifier Accuracy Score: 0.991556540987
# AdaBoostClassifier F-Measure: 0.980302435801
# AdaBoostClassifier Sensitivity: 0.987159833431
# AdaBoostClassifier Precision: 0.973739343198
# AdaBoostClassifier Area Under ROC Curve: 0.989915713154
# AdaBoostClassifier MCC: 0.975044712882
#
# n_estimators: 75
# AdaBoostClassifier Accuracy Score: 0.992132724425
# AdaBoostClassifier F-Measure: 0.981847539416
# AdaBoostClassifier Sensitivity: 0.990904587497
# AdaBoostClassifier Precision: 0.973191455322
# AdaBoostClassifier Area Under ROC Curve: 0.991663144928
# AdaBoostClassifier MCC: 0.976987579415
#
# n_estimators: 100
# AdaBoostClassifier Accuracy Score: 0.993091681926
# AdaBoostClassifier F-Measure: 0.984124725123
# AdaBoostClassifier Sensitivity: 0.990892204701
# AdaBoostClassifier Precision: 0.97766245348
# AdaBoostClassifier Area Under ROC Curve: 0.992259126439
# AdaBoostClassifier MCC: 0.979833246367
#
# n_estimators: 125
# AdaBoostClassifier Accuracy Score: 0.992900111045
# AdaBoostClassifier F-Measure: 0.983571892294
# AdaBoostClassifier Sensitivity: 0.989999347559
# AdaBoostClassifier Precision: 0.977426004736
# AdaBoostClassifier Area Under ROC Curve: 0.991819724229
# AdaBoostClassifier MCC: 0.979155969957
#
# n_estimators: 150
# AdaBoostClassifier Accuracy Score: 0.992708172465
# AdaBoostClassifier F-Measure: 0.983150044233
# AdaBoostClassifier Sensitivity: 0.989999347559
# AdaBoostClassifier Precision: 0.976578671992
# AdaBoostClassifier Area Under ROC Curve: 0.991695961852
# AdaBoostClassifier MCC: 0.97860838919
#
# n_estimators: 175
# AdaBoostClassifier Accuracy Score: 0.992708172465
# AdaBoostClassifier F-Measure: 0.983098185453
# AdaBoostClassifier Sensitivity: 0.990008164346
# AdaBoostClassifier Precision: 0.976465464757
# AdaBoostClassifier Area Under ROC Curve: 0.991703650694
# AdaBoostClassifier MCC: 0.9785602222
#
# n_estimators: 200
# AdaBoostClassifier Accuracy Score: 0.993283988204
# AdaBoostClassifier F-Measure: 0.984482027866
# AdaBoostClassifier Sensitivity: 0.990969702807
# AdaBoostClassifier Precision: 0.978250736267
# AdaBoostClassifier Area Under ROC Curve: 0.992427138372
# AdaBoostClassifier MCC: 0.980299376508
#
#
# Optimum Accuracy for AdaBoostClassifier: 0.993283988204
# Optimum Parameters:
# n_estimators=200
# C: 0.03125, gamma: 3.0517578125e-05
# Support Vector Machine Accuracy Score: 0.787757113126
# /home/muhammet/.local/lib/python2.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# /home/muhammet/.local/lib/python2.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# /home/muhammet/.local/lib/python2.7/site-packages/sklearn/metrics/classification.py:543: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# Support Vector Machine MCC: 0.0
#
# C: 0.03125, gamma: 0.0001220703125
# Support Vector Machine Accuracy Score: 0.787757113126
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine MCC: 0.0
#
# C: 0.03125, gamma: 0.00048828125
# Support Vector Machine Accuracy Score: 0.787757113126
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine MCC: 0.0
#
# C: 0.03125, gamma: 0.001953125
# Support Vector Machine Accuracy Score: 0.787757113126
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine MCC: 0.0
#
# C: 0.03125, gamma: 0.0078125
# Support Vector Machine Accuracy Score: 0.787757113126
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine MCC: 0.0
#
# C: 0.03125, gamma: 0.03125
# Support Vector Machine Accuracy Score: 0.787757113126
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine MCC: 0.0
#
# C: 0.03125, gamma: 0.125
# Support Vector Machine Accuracy Score: 0.905583500636
# Support Vector Machine F-Measure: 0.728911183668
# Support Vector Machine Sensitivity: 0.600095768575
# Support Vector Machine Precision: 0.931743129911
# Support Vector Machine Area Under ROC Curve: 0.794068692896
# Support Vector Machine MCC: 0.699699052819
#
# C: 0.03125, gamma: 0.5
# Support Vector Machine Accuracy Score: 0.982728837117
# Support Vector Machine F-Measure: 0.959692102814
# Support Vector Machine Sensitivity: 0.968363566116
# Support Vector Machine Precision: 0.951299567792
# Support Vector Machine Area Under ROC Curve: 0.977476646846
# Support Vector Machine MCC: 0.948805153208
#
# C: 0.03125, gamma: 2
# Support Vector Machine Accuracy Score: 0.989444848913
# Support Vector Machine F-Measure: 0.975743601363
# Support Vector Machine Sensitivity: 0.998220499842
# Support Vector Machine Precision: 0.954400053403
# Support Vector Machine Area Under ROC Curve: 0.992651470147
# Support Vector Machine MCC: 0.969457149891
#
# C: 0.03125, gamma: 8
# Support Vector Machine Accuracy Score: 0.988485891411
# Support Vector Machine F-Measure: 0.97326027528
# Support Vector Machine Sensitivity: 0.988251816613
# Support Vector Machine Precision: 0.958909652087
# Support Vector Machine Area Under ROC Curve: 0.988399509622
# Support Vector Machine MCC: 0.966178784565
#
# C: 0.03125, gamma: 32
# Support Vector Machine Accuracy Score: 0.988293952832
# Support Vector Machine F-Measure: 0.972790990199
# Support Vector Machine Sensitivity: 0.987317237174
# Support Vector Machine Precision: 0.958876892055
# Support Vector Machine Area Under ROC Curve: 0.987932219902
# Support Vector Machine MCC: 0.965577318105
#
# C: 0.125, gamma: 3.0517578125e-05
# Support Vector Machine Accuracy Score: 0.787757113126
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine MCC: 0.0
#
# C: 0.125, gamma: 0.0001220703125
# Support Vector Machine Accuracy Score: 0.787757113126
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine MCC: 0.0
#
# C: 0.125, gamma: 0.00048828125
# Support Vector Machine Accuracy Score: 0.787757113126
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine MCC: 0.0
#
# C: 0.125, gamma: 0.001953125
# Support Vector Machine Accuracy Score: 0.787757113126
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine MCC: 0.0
#
# C: 0.125, gamma: 0.0078125
# Support Vector Machine Accuracy Score: 0.787757113126
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine MCC: 0.0
#
# C: 0.125, gamma: 0.03125
# Support Vector Machine Accuracy Score: 0.904623807738
# Support Vector Machine F-Measure: 0.72523025998
# Support Vector Machine Sensitivity: 0.595391382838
# Support Vector Machine Precision: 0.931119977685
# Support Vector Machine Area Under ROC Curve: 0.791716500027
# Support Vector Machine MCC: 0.696209682776
#
# C: 0.125, gamma: 0.125
# Support Vector Machine Accuracy Score: 0.985222567859
# Support Vector Machine F-Measure: 0.966197696634
# Support Vector Machine Sensitivity: 0.988516294057
# Support Vector Machine Precision: 0.945086122382
# Support Vector Machine Area Under ROC Curve: 0.986454063076
# Support Vector Machine MCC: 0.95722905103
#
# C: 0.125, gamma: 0.5
# Support Vector Machine Accuracy Score: 0.989636787492
# Support Vector Machine F-Measure: 0.976199568715
# Support Vector Machine Sensitivity: 0.997358430876
# Support Vector Machine Precision: 0.956077698342
# Support Vector Machine Area Under ROC Curve: 0.992461981558
# Support Vector Machine MCC: 0.969995306524
#
# C: 0.125, gamma: 2
# Support Vector Machine Accuracy Score: 0.989636787492
# Support Vector Machine F-Measure: 0.976199568715
# Support Vector Machine Sensitivity: 0.997358430876
# Support Vector Machine Precision: 0.956077698342
# Support Vector Machine Area Under ROC Curve: 0.992461981558
# Support Vector Machine MCC: 0.969995306524
#
# C: 0.125, gamma: 8
# Support Vector Machine Accuracy Score: 0.989828726072
# Support Vector Machine F-Measure: 0.976597487295
# Support Vector Machine Sensitivity: 0.997358430876
# Support Vector Machine Precision: 0.956820555485
# Support Vector Machine Area Under ROC Curve: 0.992585743934
# Support Vector Machine MCC: 0.970496695743
#
# C: 0.125, gamma: 32
# Support Vector Machine Accuracy Score: 0.989828726072
# Support Vector Machine F-Measure: 0.976628706092
# Support Vector Machine Sensitivity: 0.997421161214
# Support Vector Machine Precision: 0.956845629622
# Support Vector Machine Area Under ROC Curve: 0.992617109103
# Support Vector Machine MCC: 0.970535603724
#
# C: 0.5, gamma: 3.0517578125e-05
# Support Vector Machine Accuracy Score: 0.787757113126
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine MCC: 0.0
#
# C: 0.5, gamma: 0.0001220703125
# Support Vector Machine Accuracy Score: 0.787757113126
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine MCC: 0.0
#
# C: 0.5, gamma: 0.00048828125
# Support Vector Machine Accuracy Score: 0.787757113126
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine MCC: 0.0
#
# C: 0.5, gamma: 0.001953125
# Support Vector Machine Accuracy Score: 0.787757113126
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine MCC: 0.0
#
# C: 0.5, gamma: 0.0078125
# Support Vector Machine Accuracy Score: 0.904048359697
# Support Vector Machine F-Measure: 0.722794594858
# Support Vector Machine Sensitivity: 0.591845727759
# Support Vector Machine Precision: 0.931863394243
# Support Vector Machine Area Under ROC Curve: 0.790067434864
# Support Vector Machine MCC: 0.694222554239
#
# C: 0.5, gamma: 0.03125
# Support Vector Machine Accuracy Score: 0.982727734022
# Support Vector Machine F-Measure: 0.960879991224
# Support Vector Machine Sensitivity: 0.991125921021
# Support Vector Machine Precision: 0.932664628643
# Support Vector Machine Area Under ROC Curve: 0.98580072355
# Support Vector Machine MCC: 0.950627899891
#
# C: 0.5, gamma: 0.125
# Support Vector Machine Accuracy Score: 0.989636787492
# Support Vector Machine F-Measure: 0.976198976308
# Support Vector Machine Sensitivity: 0.998275862069
# Support Vector Machine Precision: 0.955236201503
# Support Vector Machine Area Under ROC Curve: 0.992800215226
# Support Vector Machine MCC: 0.970026195211
#
# C: 0.5, gamma: 0.5
# Support Vector Machine Accuracy Score: 0.989252910333
# Support Vector Machine F-Measure: 0.975309776601
# Support Vector Machine Sensitivity: 0.997421161214
# Support Vector Machine Precision: 0.954344362693
# Support Vector Machine Area Under ROC Curve: 0.99225381718
# Support Vector Machine MCC: 0.968904111115
#
# C: 0.5, gamma: 2
# Support Vector Machine Accuracy Score: 0.989828726072
# Support Vector Machine F-Measure: 0.976659745706
# Support Vector Machine Sensitivity: 0.998275862069
# Support Vector Machine Precision: 0.956136643229
# Support Vector Machine Area Under ROC Curve: 0.992920697154
# Support Vector Machine MCC: 0.970599763677
#
# C: 0.5, gamma: 8
# Support Vector Machine Accuracy Score: 0.989828726072
# Support Vector Machine F-Measure: 0.976597487295
# Support Vector Machine Sensitivity: 0.997358430876
# Support Vector Machine Precision: 0.956820555485
# Support Vector Machine Area Under ROC Curve: 0.992585743934
# Support Vector Machine MCC: 0.970496695743
#
# C: 0.5, gamma: 32
# Support Vector Machine Accuracy Score: 0.990020664652
# Support Vector Machine F-Measure: 0.977084944893
# Support Vector Machine Sensitivity: 0.997428529325
# Support Vector Machine Precision: 0.957716011208
# Support Vector Machine Area Under ROC Curve: 0.992741566105
# Support Vector Machine MCC: 0.97109917018
#
# C: 2, gamma: 3.0517578125e-05
# Support Vector Machine Accuracy Score: 0.787757113126
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine MCC: 0.0
#
# C: 2, gamma: 0.0001220703125
# Support Vector Machine Accuracy Score: 0.787757113126
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine MCC: 0.0
#
# C: 2, gamma: 0.00048828125
# Support Vector Machine Accuracy Score: 0.787757113126
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine MCC: 0.0
#
# C: 2, gamma: 0.001953125
# Support Vector Machine Accuracy Score: 0.903856421118
# Support Vector Machine F-Measure: 0.722110332883
# Support Vector Machine Sensitivity: 0.590983658793
# Support Vector Machine Precision: 0.93180303207
# Support Vector Machine Area Under ROC Curve: 0.789636400381
# Support Vector Machine MCC: 0.69359206916
#
# C: 2, gamma: 0.0078125
# Support Vector Machine Accuracy Score: 0.981384531663
# Support Vector Machine F-Measure: 0.957957128747
# Support Vector Machine Sensitivity: 0.991125921021
# Support Vector Machine Precision: 0.927203947499
# Support Vector Machine Area Under ROC Curve: 0.984947197275
# Support Vector Machine MCC: 0.946994105852
#
# C: 2, gamma: 0.03125
# Support Vector Machine Accuracy Score: 0.989636787492
# Support Vector Machine F-Measure: 0.976198976308
# Support Vector Machine Sensitivity: 0.998275862069
# Support Vector Machine Precision: 0.955236201503
# Support Vector Machine Area Under ROC Curve: 0.992800215226
# Support Vector Machine MCC: 0.970026195211
#
# C: 2, gamma: 0.125
# Support Vector Machine Accuracy Score: 0.988485523713
# Support Vector Machine F-Measure: 0.973594132285
# Support Vector Machine Sensitivity: 0.997421161214
# Support Vector Machine Precision: 0.951031256327
# Support Vector Machine Area Under ROC Curve: 0.991764742717
# Support Vector Machine MCC: 0.966742740783
#
# C: 2, gamma: 0.5
# Support Vector Machine Accuracy Score: 0.988293585133
# Support Vector Machine F-Measure: 0.973152370428
# Support Vector Machine Sensitivity: 0.992254799798
# Support Vector Machine Precision: 0.954952081642
# Support Vector Machine Area Under ROC Curve: 0.989789684091
# Support Vector Machine MCC: 0.966028317827
#
# C: 2, gamma: 2
# Support Vector Machine Accuracy Score: 0.989636787492
# Support Vector Machine F-Measure: 0.976199568715
# Support Vector Machine Sensitivity: 0.997358430876
# Support Vector Machine Precision: 0.956077698342
# Support Vector Machine Area Under ROC Curve: 0.992461981558
# Support Vector Machine MCC: 0.969995306524
#
# C: 2, gamma: 8
# Support Vector Machine Accuracy Score: 0.990020664652
# Support Vector Machine F-Measure: 0.977033930284
# Support Vector Machine Sensitivity: 0.998220499842
# Support Vector Machine Precision: 0.956849041456
# Support Vector Machine Area Under ROC Curve: 0.993016778417
# Support Vector Machine MCC: 0.971063534197
#
# C: 2, gamma: 32
# Support Vector Machine Accuracy Score: 0.993091314228
# Support Vector Machine F-Measure: 0.983881195931
# Support Vector Machine Sensitivity: 0.991782681366
# Support Vector Machine Precision: 0.976254211054
# Support Vector Machine Area Under ROC Curve: 0.992598047401
# Support Vector Machine MCC: 0.979592929911
#
# C: 8, gamma: 3.0517578125e-05
# Support Vector Machine Accuracy Score: 0.787757113126
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine MCC: 0.0
#
# C: 8, gamma: 0.0001220703125
# Support Vector Machine Accuracy Score: 0.787757113126
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine MCC: 0.0
#
# C: 8, gamma: 0.00048828125
# Support Vector Machine Accuracy Score: 0.903856421118
# Support Vector Machine F-Measure: 0.722110332883
# Support Vector Machine Sensitivity: 0.590983658793
# Support Vector Machine Precision: 0.93180303207
# Support Vector Machine Area Under ROC Curve: 0.789636400381
# Support Vector Machine MCC: 0.69359206916
#
# C: 8, gamma: 0.001953125
# Support Vector Machine Accuracy Score: 0.982152285981
# Support Vector Machine F-Measure: 0.959810570341
# Support Vector Machine Sensitivity: 0.995649029167
# Support Vector Machine Precision: 0.926756476905
# Support Vector Machine Area Under ROC Curve: 0.987087978401
# Support Vector Machine MCC: 0.949486518103
#
# C: 8, gamma: 0.0078125
# Support Vector Machine Accuracy Score: 0.989636787492
# Support Vector Machine F-Measure: 0.976198976308
# Support Vector Machine Sensitivity: 0.998275862069
# Support Vector Machine Precision: 0.955236201503
# Support Vector Machine Area Under ROC Curve: 0.992800215226
# Support Vector Machine MCC: 0.970026195211
#
# C: 8, gamma: 0.03125
# Support Vector Machine Accuracy Score: 0.987718137093
# Support Vector Machine F-Measure: 0.971852769707
# Support Vector Machine Sensitivity: 0.993964201507
# Support Vector Machine Precision: 0.950844773138
# Support Vector Machine Area Under ROC Curve: 0.990036262864
# Support Vector Machine MCC: 0.964441064513
#
# C: 8, gamma: 0.125
# Support Vector Machine Accuracy Score: 0.987526198513
# Support Vector Machine F-Measure: 0.97133999899
# Support Vector Machine Sensitivity: 0.988672379415
# Support Vector Machine Precision: 0.954743647026
# Support Vector Machine Area Under ROC Curve: 0.987998473899
# Support Vector Machine MCC: 0.963660325359
#
# C: 8, gamma: 0.5
# Support Vector Machine Accuracy Score: 0.989444848913
# Support Vector Machine F-Measure: 0.975770610521
# Support Vector Machine Sensitivity: 0.996503730022
# Support Vector Machine Precision: 0.956043827593
# Support Vector Machine Area Under ROC Curve: 0.99203463113
# Support Vector Machine MCC: 0.969429757352
#
# C: 8, gamma: 2
# Support Vector Machine Accuracy Score: 0.989636787492
# Support Vector Machine F-Measure: 0.976199568715
# Support Vector Machine Sensitivity: 0.997358430876
# Support Vector Machine Precision: 0.956077698342
# Support Vector Machine Area Under ROC Curve: 0.992461981558
# Support Vector Machine MCC: 0.969995306524
#
# C: 8, gamma: 8
# Support Vector Machine Accuracy Score: 0.989828726072
# Support Vector Machine F-Measure: 0.976543211274
# Support Vector Machine Sensitivity: 0.996351340963
# Support Vector Machine Precision: 0.957674867281
# Support Vector Machine Area Under ROC Curve: 0.992202971924
# Support Vector Machine MCC: 0.970428833546
#
# C: 8, gamma: 32
# Support Vector Machine Accuracy Score: 0.993667129967
# Support Vector Machine F-Measure: 0.985177038201
# Support Vector Machine Sensitivity: 0.990809730602
# Support Vector Machine Precision: 0.979692525826
# Support Vector Machine Area Under ROC Curve: 0.992596794875
# Support Vector Machine MCC: 0.981207877079
#
# C: 32, gamma: 3.0517578125e-05
# Support Vector Machine Accuracy Score: 0.787757113126
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine MCC: 0.0
#
# C: 32, gamma: 0.0001220703125
# Support Vector Machine Accuracy Score: 0.903664482538
# Support Vector Machine F-Measure: 0.721328339139
# Support Vector Machine Sensitivity: 0.590066227601
# Support Vector Machine Precision: 0.931649422239
# Support Vector Machine Area Under ROC Curve: 0.789177684785
# Support Vector Machine MCC: 0.692879332674
#
# C: 32, gamma: 0.00048828125
# Support Vector Machine Accuracy Score: 0.981960347401
# Support Vector Machine F-Measure: 0.959327694548
# Support Vector Machine Sensitivity: 0.994687490705
# Support Vector Machine Precision: 0.926721862852
# Support Vector Machine Area Under ROC Curve: 0.98660720917
# Support Vector Machine MCC: 0.948871848181
#
# C: 32, gamma: 0.001953125
# Support Vector Machine Accuracy Score: 0.989636787492
# Support Vector Machine F-Measure: 0.976198976308
# Support Vector Machine Sensitivity: 0.998275862069
# Support Vector Machine Precision: 0.955236201503
# Support Vector Machine Area Under ROC Curve: 0.992800215226
# Support Vector Machine MCC: 0.970026195211
#
# C: 32, gamma: 0.0078125
# Support Vector Machine Accuracy Score: 0.988101646554
# Support Vector Machine F-Measure: 0.972733520636
# Support Vector Machine Sensitivity: 0.995711759505
# Support Vector Machine Precision: 0.950916048954
# Support Vector Machine Area Under ROC Curve: 0.990910041863
# Support Vector Machine MCC: 0.965590811286
#
# C: 32, gamma: 0.03125
# Support Vector Machine Accuracy Score: 0.987334259933
# Support Vector Machine F-Measure: 0.970879757477
# Support Vector Machine Sensitivity: 0.988672379415
# Support Vector Machine Precision: 0.953885678966
# Support Vector Machine Area Under ROC Curve: 0.98787942628
# Support Vector Machine MCC: 0.963103790434
#
# C: 32, gamma: 0.125
# Support Vector Machine Accuracy Score: 0.987142321354
# Support Vector Machine F-Measure: 0.970402938159
# Support Vector Machine Sensitivity: 0.98682021144
# Support Vector Machine Precision: 0.954654099522
# Support Vector Machine Area Under ROC Curve: 0.987072389912
# Support Vector Machine MCC: 0.962454748078
#
# C: 32, gamma: 0.5
# Support Vector Machine Accuracy Score: 0.989636787492
# Support Vector Machine F-Measure: 0.976199568715
# Support Vector Machine Sensitivity: 0.997358430876
# Support Vector Machine Precision: 0.956077698342
# Support Vector Machine Area Under ROC Curve: 0.992461981558
# Support Vector Machine MCC: 0.969995306524
#
# C: 32, gamma: 2
# Support Vector Machine Accuracy Score: 0.989828726072
# Support Vector Machine F-Measure: 0.976597487295
# Support Vector Machine Sensitivity: 0.997358430876
# Support Vector Machine Precision: 0.956820555485
# Support Vector Machine Area Under ROC Curve: 0.992585743934
# Support Vector Machine MCC: 0.970496695743
#
# C: 32, gamma: 8
# Support Vector Machine Accuracy Score: 0.992899375648
# Support Vector Machine F-Measure: 0.98338981681
# Support Vector Machine Sensitivity: 0.99164728321
# Support Vector Machine Precision: 0.975411785009
# Support Vector Machine Area Under ROC Curve: 0.992406585947
# Support Vector Machine MCC: 0.978984788712
#
# C: 32, gamma: 32
# Support Vector Machine Accuracy Score: 0.993283988204
# Support Vector Machine F-Measure: 0.984300579759
# Support Vector Machine Sensitivity: 0.988186463708
# Support Vector Machine Precision: 0.980489754038
# Support Vector Machine Area Under ROC Curve: 0.991406520652
# Support Vector Machine MCC: 0.980056006595
#
# C: 128, gamma: 3.0517578125e-05
# Support Vector Machine Accuracy Score: 0.903664482538
# Support Vector Machine F-Measure: 0.721434067613
# Support Vector Machine Sensitivity: 0.590128957939
# Support Vector Machine Precision: 0.931676905944
# Support Vector Machine Area Under ROC Curve: 0.789209049954
# Support Vector Machine MCC: 0.69294621464
#
# C: 128, gamma: 0.0001220703125
# Support Vector Machine Accuracy Score: 0.982152285981
# Support Vector Machine F-Measure: 0.959810570341
# Support Vector Machine Sensitivity: 0.995649029167
# Support Vector Machine Precision: 0.926756476905
# Support Vector Machine Area Under ROC Curve: 0.987087978401
# Support Vector Machine MCC: 0.949486518103
#
# C: 128, gamma: 0.00048828125
# Support Vector Machine Accuracy Score: 0.989636787492
# Support Vector Machine F-Measure: 0.976198976308
# Support Vector Machine Sensitivity: 0.998275862069
# Support Vector Machine Precision: 0.955236201503
# Support Vector Machine Area Under ROC Curve: 0.992800215226
# Support Vector Machine MCC: 0.970026195211
#
# C: 128, gamma: 0.001953125
# Support Vector Machine Accuracy Score: 0.987910075672
# Support Vector Machine F-Measure: 0.972285347802
# Support Vector Machine Sensitivity: 0.994818902362
# Support Vector Machine Precision: 0.9508792084
# Support Vector Machine Area Under ROC Curve: 0.990463613291
# Support Vector Machine MCC: 0.965007072237
#
# C: 128, gamma: 0.0078125
# Support Vector Machine Accuracy Score: 0.987334259933
# Support Vector Machine F-Measure: 0.970899809709
# Support Vector Machine Sensitivity: 0.98781031045
# Support Vector Machine Precision: 0.954714674115
# Support Vector Machine Area Under ROC Curve: 0.987567439417
# Support Vector Machine MCC: 0.963092990016
#
# C: 128, gamma: 0.03125
# Support Vector Machine Accuracy Score: 0.987142321354
# Support Vector Machine F-Measure: 0.970402938159
# Support Vector Machine Sensitivity: 0.98682021144
# Support Vector Machine Precision: 0.954654099522
# Support Vector Machine Area Under ROC Curve: 0.987072389912
# Support Vector Machine MCC: 0.962454748078
#
# C: 128, gamma: 0.125
# Support Vector Machine Accuracy Score: 0.989444848913
# Support Vector Machine F-Measure: 0.975770610521
# Support Vector Machine Sensitivity: 0.996503730022
# Support Vector Machine Precision: 0.956043827593
# Support Vector Machine Area Under ROC Curve: 0.99203463113
# Support Vector Machine MCC: 0.969429757352
#
# C: 128, gamma: 0.5
# Support Vector Machine Accuracy Score: 0.989636787492
# Support Vector Machine F-Measure: 0.976199568715
# Support Vector Machine Sensitivity: 0.997358430876
# Support Vector Machine Precision: 0.956077698342
# Support Vector Machine Area Under ROC Curve: 0.992461981558
# Support Vector Machine MCC: 0.969995306524
#
# C: 128, gamma: 2
# Support Vector Machine Accuracy Score: 0.990020664652
# Support Vector Machine F-Measure: 0.977033930284
# Support Vector Machine Sensitivity: 0.998220499842
# Support Vector Machine Precision: 0.956849041456
# Support Vector Machine Area Under ROC Curve: 0.993016778417
# Support Vector Machine MCC: 0.971063534197
#
# C: 128, gamma: 8
# Support Vector Machine Accuracy Score: 0.993284355903
# Support Vector Machine F-Measure: 0.98429874316
# Support Vector Machine Sensitivity: 0.989878717171
# Support Vector Machine Precision: 0.978856930261
# Support Vector Machine Area Under ROC Curve: 0.992006933787
# Support Vector Machine MCC: 0.980080927725
#
# C: 128, gamma: 32
# Support Vector Machine Accuracy Score: 0.993284355903
# Support Vector Machine F-Measure: 0.984330161817
# Support Vector Machine Sensitivity: 0.986438905711
# Support Vector Machine Precision: 0.982314287623
# Support Vector Machine Area Under ROC Curve: 0.990775551648
# Support Vector Machine MCC: 0.980091664492
#
# C: 512, gamma: 3.0517578125e-05
# Support Vector Machine Accuracy Score: 0.981576837941
# Support Vector Machine F-Measure: 0.958511803136
# Support Vector Machine Sensitivity: 0.994687490705
# Support Vector Machine Precision: 0.925194691984
# Support Vector Machine Area Under ROC Curve: 0.986361495575
# Support Vector Machine MCC: 0.947849951379
#
# C: 512, gamma: 0.0001220703125
# Support Vector Machine Accuracy Score: 0.989636787492
# Support Vector Machine F-Measure: 0.976198976308
# Support Vector Machine Sensitivity: 0.998275862069
# Support Vector Machine Precision: 0.955236201503
# Support Vector Machine Area Under ROC Curve: 0.992800215226
# Support Vector Machine MCC: 0.970026195211
#
# C: 512, gamma: 0.00048828125
# Support Vector Machine Accuracy Score: 0.987910075672
# Support Vector Machine F-Measure: 0.972285347802
# Support Vector Machine Sensitivity: 0.994818902362
# Support Vector Machine Precision: 0.9508792084
# Support Vector Machine Area Under ROC Curve: 0.990463613291
# Support Vector Machine MCC: 0.965007072237
#
# C: 512, gamma: 0.001953125
# Support Vector Machine Accuracy Score: 0.987142321354
# Support Vector Machine F-Measure: 0.970402938159
# Support Vector Machine Sensitivity: 0.98682021144
# Support Vector Machine Precision: 0.954654099522
# Support Vector Machine Area Under ROC Curve: 0.987072389912
# Support Vector Machine MCC: 0.962454748078
#
# C: 512, gamma: 0.0078125
# Support Vector Machine Accuracy Score: 0.987142321354
# Support Vector Machine F-Measure: 0.970402938159
# Support Vector Machine Sensitivity: 0.98682021144
# Support Vector Machine Precision: 0.954654099522
# Support Vector Machine Area Under ROC Curve: 0.987072389912
# Support Vector Machine MCC: 0.962454748078
#
# C: 512, gamma: 0.03125
# Support Vector Machine Accuracy Score: 0.987142321354
# Support Vector Machine F-Measure: 0.970395257845
# Support Vector Machine Sensitivity: 0.985902780247
# Support Vector Machine Precision: 0.955493519128
# Support Vector Machine Area Under ROC Curve: 0.986734156243
# Support Vector Machine MCC: 0.962422221328
#
# C: 512, gamma: 0.125
# Support Vector Machine Accuracy Score: 0.989636787492
# Support Vector Machine F-Measure: 0.976199568715
# Support Vector Machine Sensitivity: 0.997358430876
# Support Vector Machine Precision: 0.956077698342
# Support Vector Machine Area Under ROC Curve: 0.992461981558
# Support Vector Machine MCC: 0.969995306524
#
# C: 512, gamma: 0.5
# Support Vector Machine Accuracy Score: 0.989636787492
# Support Vector Machine F-Measure: 0.976199568715
# Support Vector Machine Sensitivity: 0.997358430876
# Support Vector Machine Precision: 0.956077698342
# Support Vector Machine Area Under ROC Curve: 0.992461981558
# Support Vector Machine MCC: 0.969995306524
#
# C: 512, gamma: 2
# Support Vector Machine Accuracy Score: 0.99078841897
# Support Vector Machine F-Measure: 0.978660765434
# Support Vector Machine Sensitivity: 0.992679104517
# Support Vector Machine Precision: 0.965251565621
# Support Vector Machine Area Under ROC Curve: 0.991461366824
# Support Vector Machine MCC: 0.973031997326
#
# C: 512, gamma: 8
# Support Vector Machine Accuracy Score: 0.993283988204
# Support Vector Machine F-Measure: 0.984297590208
# Support Vector Machine Sensitivity: 0.989878717171
# Support Vector Machine Precision: 0.978880909082
# Support Vector Machine Area Under ROC Curve: 0.992007525784
# Support Vector Machine MCC: 0.980090662182
#
# C: 512, gamma: 32
# Support Vector Machine Accuracy Score: 0.994243681103
# Support Vector Machine F-Measure: 0.986445072763
# Support Vector Machine Sensitivity: 0.987169620712
# Support Vector Machine Precision: 0.985826389126
# Support Vector Machine Area Under ROC Curve: 0.991628754915
# Support Vector Machine MCC: 0.982831551728
#
# C: 2048, gamma: 3.0517578125e-05
# Support Vector Machine Accuracy Score: 0.989636787492
# Support Vector Machine F-Measure: 0.976198976308
# Support Vector Machine Sensitivity: 0.998275862069
# Support Vector Machine Precision: 0.955236201503
# Support Vector Machine Area Under ROC Curve: 0.992800215226
# Support Vector Machine MCC: 0.970026195211
#
# C: 2048, gamma: 0.0001220703125
# Support Vector Machine Accuracy Score: 0.987718137093
# Support Vector Machine F-Measure: 0.971852769707
# Support Vector Machine Sensitivity: 0.993964201507
# Support Vector Machine Precision: 0.950844773138
# Support Vector Machine Area Under ROC Curve: 0.990036262864
# Support Vector Machine MCC: 0.964441064513
#
# C: 2048, gamma: 0.00048828125
# Support Vector Machine Accuracy Score: 0.986950382774
# Support Vector Machine F-Measure: 0.969988426586
# Support Vector Machine Sensitivity: 0.98682021144
# Support Vector Machine Precision: 0.953835614805
# Support Vector Machine Area Under ROC Curve: 0.986948933122
# Support Vector Machine MCC: 0.961919814175
#
# C: 2048, gamma: 0.001953125
# Support Vector Machine Accuracy Score: 0.987142321354
# Support Vector Machine F-Measure: 0.970402938159
# Support Vector Machine Sensitivity: 0.98682021144
# Support Vector Machine Precision: 0.954654099522
# Support Vector Machine Area Under ROC Curve: 0.987072389912
# Support Vector Machine MCC: 0.962454748078
#
# C: 2048, gamma: 0.0078125
# Support Vector Machine Accuracy Score: 0.987142321354
# Support Vector Machine F-Measure: 0.970402938159
# Support Vector Machine Sensitivity: 0.98682021144
# Support Vector Machine Precision: 0.954654099522
# Support Vector Machine Area Under ROC Curve: 0.987072389912
# Support Vector Machine MCC: 0.962454748078
#
# C: 2048, gamma: 0.03125
# Support Vector Machine Accuracy Score: 0.989444848913
# Support Vector Machine F-Measure: 0.975770610521
# Support Vector Machine Sensitivity: 0.996503730022
# Support Vector Machine Precision: 0.956043827593
# Support Vector Machine Area Under ROC Curve: 0.99203463113
# Support Vector Machine MCC: 0.969429757352
#
# C: 2048, gamma: 0.125
# Support Vector Machine Accuracy Score: 0.989636787492
# Support Vector Machine F-Measure: 0.976199568715
# Support Vector Machine Sensitivity: 0.997358430876
# Support Vector Machine Precision: 0.956077698342
# Support Vector Machine Area Under ROC Curve: 0.992461981558
# Support Vector Machine MCC: 0.969995306524
#
# C: 2048, gamma: 0.5
# Support Vector Machine Accuracy Score: 0.989828726072
# Support Vector Machine F-Measure: 0.976597487295
# Support Vector Machine Sensitivity: 0.997358430876
# Support Vector Machine Precision: 0.956820555485
# Support Vector Machine Area Under ROC Curve: 0.992585743934
# Support Vector Machine MCC: 0.970496695743
#
# C: 2048, gamma: 2
# Support Vector Machine Accuracy Score: 0.992132356726
# Support Vector Machine F-Measure: 0.981587727837
# Support Vector Machine Sensitivity: 0.987190628754
# Support Vector Machine Precision: 0.976182859251
# Support Vector Machine Area Under ROC Curve: 0.990299312356
# Support Vector Machine MCC: 0.976661494864
#
# C: 2048, gamma: 8
# Support Vector Machine Accuracy Score: 0.993476294482
# Support Vector Machine F-Measure: 0.984687754307
# Support Vector Machine Sensitivity: 0.987186768959
# Support Vector Machine Precision: 0.982294761249
# Support Vector Machine Area Under ROC Curve: 0.991150360568
# Support Vector Machine MCC: 0.980583073932
#
# C: 2048, gamma: 32
# Support Vector Machine Accuracy Score: 0.993283988204
# Support Vector Machine F-Measure: 0.984163977547
# Support Vector Machine Sensitivity: 0.982550151739
# Support Vector Machine Precision: 0.985887465395
# Support Vector Machine Area Under ROC Curve: 0.989314305671
# Support Vector Machine MCC: 0.979942012051
#
# C: 8192, gamma: 3.0517578125e-05
# Support Vector Machine Accuracy Score: 0.988101646554
# Support Vector Machine F-Measure: 0.972733520636
# Support Vector Machine Sensitivity: 0.995711759505
# Support Vector Machine Precision: 0.950916048954
# Support Vector Machine Area Under ROC Curve: 0.990910041863
# Support Vector Machine MCC: 0.965590811286
#
# C: 8192, gamma: 0.0001220703125
# Support Vector Machine Accuracy Score: 0.986950382774
# Support Vector Machine F-Measure: 0.969988426586
# Support Vector Machine Sensitivity: 0.98682021144
# Support Vector Machine Precision: 0.953835614805
# Support Vector Machine Area Under ROC Curve: 0.986948933122
# Support Vector Machine MCC: 0.961919814175
#
# C: 8192, gamma: 0.00048828125
# Support Vector Machine Accuracy Score: 0.986950382774
# Support Vector Machine F-Measure: 0.969973905787
# Support Vector Machine Sensitivity: 0.985965510585
# Support Vector Machine Precision: 0.954626551313
# Support Vector Machine Area Under ROC Curve: 0.986645039484
# Support Vector Machine MCC: 0.961891904841
#
# C: 8192, gamma: 0.001953125
# Support Vector Machine Accuracy Score: 0.986950382774
# Support Vector Machine F-Measure: 0.969973905787
# Support Vector Machine Sensitivity: 0.985965510585
# Support Vector Machine Precision: 0.954626551313
# Support Vector Machine Area Under ROC Curve: 0.986645039484
# Support Vector Machine MCC: 0.961891904841
#
# C: 8192, gamma: 0.0078125
# Support Vector Machine Accuracy Score: 0.987142321354
# Support Vector Machine F-Measure: 0.970395257845
# Support Vector Machine Sensitivity: 0.985902780247
# Support Vector Machine Precision: 0.955493519128
# Support Vector Machine Area Under ROC Curve: 0.986734156243
# Support Vector Machine MCC: 0.962422221328
#
# C: 8192, gamma: 0.03125
# Support Vector Machine Accuracy Score: 0.989636787492
# Support Vector Machine F-Measure: 0.976199568715
# Support Vector Machine Sensitivity: 0.997358430876
# Support Vector Machine Precision: 0.956077698342
# Support Vector Machine Area Under ROC Curve: 0.992461981558
# Support Vector Machine MCC: 0.969995306524
#
# C: 8192, gamma: 0.125
# Support Vector Machine Accuracy Score: 0.989444848913
# Support Vector Machine F-Measure: 0.975788190775
# Support Vector Machine Sensitivity: 0.997358430876
# Support Vector Machine Precision: 0.95528512281
# Support Vector Machine Area Under ROC Curve: 0.992338219182
# Support Vector Machine MCC: 0.969471596013
#
# C: 8192, gamma: 0.5
# Support Vector Machine Accuracy Score: 0.990020664652
# Support Vector Machine F-Measure: 0.977024822196
# Support Vector Machine Sensitivity: 0.998203351595
# Support Vector Machine Precision: 0.956875226309
# Support Vector Machine Area Under ROC Curve: 0.993008204293
# Support Vector Machine MCC: 0.97106652489
#
# C: 8192, gamma: 2
# Support Vector Machine Accuracy Score: 0.992516233886
# Support Vector Machine F-Measure: 0.982523684046
# Support Vector Machine Sensitivity: 0.986353076146
# Support Vector Machine Precision: 0.978812195635
# Support Vector Machine Area Under ROC Curve: 0.990244705271
# Support Vector Machine MCC: 0.977806620338
#
# C: 8192, gamma: 8
# Support Vector Machine Accuracy Score: 0.99309315272
# Support Vector Machine F-Measure: 0.983670283157
# Support Vector Machine Sensitivity: 0.985265656518
# Support Vector Machine Precision: 0.982205715701
# Support Vector Machine Area Under ROC Curve: 0.990189804347
# Support Vector Machine MCC: 0.979340536554
#
# C: 8192, gamma: 32
# Support Vector Machine Accuracy Score: 0.992708172465
# Support Vector Machine F-Measure: 0.98295817243
# Support Vector Machine Sensitivity: 0.982709908908
# Support Vector Machine Precision: 0.983306947847
# Support Vector Machine Area Under ROC Curve: 0.989027688866
# Support Vector Machine MCC: 0.978356284843
#
# C: 32768, gamma: 3.0517578125e-05
# Support Vector Machine Accuracy Score: 0.986950382774
# Support Vector Machine F-Measure: 0.969988426586
# Support Vector Machine Sensitivity: 0.98682021144
# Support Vector Machine Precision: 0.953835614805
# Support Vector Machine Area Under ROC Curve: 0.986948933122
# Support Vector Machine MCC: 0.961919814175
#
# C: 32768, gamma: 0.0001220703125
# Support Vector Machine Accuracy Score: 0.986950382774
# Support Vector Machine F-Measure: 0.969973905787
# Support Vector Machine Sensitivity: 0.985965510585
# Support Vector Machine Precision: 0.954626551313
# Support Vector Machine Area Under ROC Curve: 0.986645039484
# Support Vector Machine MCC: 0.961891904841
#
# C: 32768, gamma: 0.00048828125
# Support Vector Machine Accuracy Score: 0.986950382774
# Support Vector Machine F-Measure: 0.969973905787
# Support Vector Machine Sensitivity: 0.985965510585
# Support Vector Machine Precision: 0.954626551313
# Support Vector Machine Area Under ROC Curve: 0.986645039484
# Support Vector Machine MCC: 0.961891904841
#
# C: 32768, gamma: 0.001953125
# Support Vector Machine Accuracy Score: 0.987142321354
# Support Vector Machine F-Measure: 0.970402938159
# Support Vector Machine Sensitivity: 0.98682021144
# Support Vector Machine Precision: 0.954654099522
# Support Vector Machine Area Under ROC Curve: 0.987072389912
# Support Vector Machine MCC: 0.962454748078
#
# C: 32768, gamma: 0.0078125
# Support Vector Machine Accuracy Score: 0.989444848913
# Support Vector Machine F-Measure: 0.975770610521
# Support Vector Machine Sensitivity: 0.996503730022
# Support Vector Machine Precision: 0.956043827593
# Support Vector Machine Area Under ROC Curve: 0.99203463113
# Support Vector Machine MCC: 0.969429757352
#
# C: 32768, gamma: 0.03125
# Support Vector Machine Accuracy Score: 0.989444848913
# Support Vector Machine F-Measure: 0.975788190775
# Support Vector Machine Sensitivity: 0.997358430876
# Support Vector Machine Precision: 0.95528512281
# Support Vector Machine Area Under ROC Curve: 0.992338219182
# Support Vector Machine MCC: 0.969471596013
#
# C: 32768, gamma: 0.125
# Support Vector Machine Accuracy Score: 0.989636787492
# Support Vector Machine F-Measure: 0.976186109355
# Support Vector Machine Sensitivity: 0.997358430876
# Support Vector Machine Precision: 0.956027979953
# Support Vector Machine Area Under ROC Curve: 0.992461981558
# Support Vector Machine MCC: 0.969972985233
#
# C: 32768, gamma: 0.5
# Support Vector Machine Accuracy Score: 0.990980725248
# Support Vector Machine F-Measure: 0.979037415487
# Support Vector Machine Sensitivity: 0.991744525077
# Support Vector Machine Precision: 0.966857594323
# Support Vector Machine Area Under ROC Curve: 0.991238087084
# Support Vector Machine MCC: 0.973502743537
#
# C: 32768, gamma: 2
# Support Vector Machine Accuracy Score: 0.993092417323
# Support Vector Machine F-Measure: 0.983814446036
# Support Vector Machine Sensitivity: 0.986314919857
# Support Vector Machine Precision: 0.981411933536
# Support Vector Machine Area Under ROC Curve: 0.99059210795
# Support Vector Machine MCC: 0.979460128299
#
# C: 32768, gamma: 8
# Support Vector Machine Accuracy Score: 0.992516969282
# Support Vector Machine F-Measure: 0.982363543502
# Support Vector Machine Sensitivity: 0.980784451506
# Support Vector Machine Precision: 0.98404688912
# Support Vector Machine Area Under ROC Curve: 0.988189022407
# Support Vector Machine MCC: 0.977652411502
#
# C: 32768, gamma: 32
# Support Vector Machine Accuracy Score: 0.990980725248
# Support Vector Machine F-Measure: 0.978856550822
# Support Vector Machine Sensitivity: 0.979068460639
# Support Vector Machine Precision: 0.978743717574
# Support Vector Machine Area Under ROC Curve: 0.986598871362
# Support Vector Machine MCC: 0.97315851827
#
#
# Optimum Accuracy for Support Vector Machine: 0.994243681103
# Optimum Parameters:
# C:512, gamma:32
# n_neighbors: 1
# K-Nearest Neighbour Accuracy Score: 0.993859436245
# K-Nearest Neighbour F-Measure: 0.98571521875
# K-Nearest Neighbour Sensitivity: 0.984768838674
# K-Nearest Neighbour Precision: 0.986799048281
# K-Nearest Neighbour Area Under ROC Curve: 0.990546774814
# K-Nearest Neighbour MCC: 0.981858185208
#
# n_neighbors: 5
# K-Nearest Neighbour Accuracy Score: 0.992131989028
# K-Nearest Neighbour F-Measure: 0.9815471191
# K-Nearest Neighbour Sensitivity: 0.985360589512
# K-Nearest Neighbour Precision: 0.977895694259
# K-Nearest Neighbour Area Under ROC Curve: 0.989629505884
# K-Nearest Neighbour MCC: 0.97660893664
#
# n_neighbors: 10
# K-Nearest Neighbour Accuracy Score: 0.992899375648
# K-Nearest Neighbour F-Measure: 0.983524704869
# K-Nearest Neighbour Sensitivity: 0.993644472133
# K-Nearest Neighbour Precision: 0.973768062528
# K-Nearest Neighbour Area Under ROC Curve: 0.993163339258
# K-Nearest Neighbour MCC: 0.979144452911
#
# n_neighbors: 15
# K-Nearest Neighbour Accuracy Score: 0.992899375648
# K-Nearest Neighbour F-Measure: 0.983487692183
# K-Nearest Neighbour Sensitivity: 0.994506541099
# K-Nearest Neighbour Precision: 0.972867047834
# K-Nearest Neighbour Area Under ROC Curve: 0.993475326122
# K-Nearest Neighbour MCC: 0.979123934167
#
# n_neighbors: 20
# K-Nearest Neighbour Accuracy Score: 0.992899375648
# K-Nearest Neighbour F-Measure: 0.983487692183
# K-Nearest Neighbour Sensitivity: 0.994506541099
# K-Nearest Neighbour Precision: 0.972867047834
# K-Nearest Neighbour Area Under ROC Curve: 0.993475326122
# K-Nearest Neighbour MCC: 0.979123934167
#
# n_neighbors: 25
# K-Nearest Neighbour Accuracy Score: 0.990788051272
# K-Nearest Neighbour F-Measure: 0.978566482042
# K-Nearest Neighbour Sensitivity: 0.98668877273
# K-Nearest Neighbour Precision: 0.970665087949
# K-Nearest Neighbour Area Under ROC Curve: 0.989326633784
# K-Nearest Neighbour MCC: 0.97278380378
#
# n_neighbors: 30
# K-Nearest Neighbour Accuracy Score: 0.990020296953
# K-Nearest Neighbour F-Measure: 0.976601595123
# K-Nearest Neighbour Sensitivity: 0.9810422821
# K-Nearest Neighbour Precision: 0.972263782405
# K-Nearest Neighbour Area Under ROC Curve: 0.986744651769
# K-Nearest Neighbour MCC: 0.970294893709
#
# n_neighbors: 35
# K-Nearest Neighbour Accuracy Score: 0.989060971753
# K-Nearest Neighbour F-Measure: 0.97448756524
# K-Nearest Neighbour Sensitivity: 0.983766356869
# K-Nearest Neighbour Precision: 0.965499173281
# K-Nearest Neighbour Area Under ROC Curve: 0.987132879799
# K-Nearest Neighbour MCC: 0.96763602777
#
# n_neighbors: 40
# K-Nearest Neighbour Accuracy Score: 0.988869768571
# K-Nearest Neighbour F-Measure: 0.974322872343
# K-Nearest Neighbour Sensitivity: 0.990118297669
# K-Nearest Neighbour Precision: 0.959371851908
# K-Nearest Neighbour Area Under ROC Curve: 0.989327072268
# K-Nearest Neighbour MCC: 0.967556331542
#
# n_neighbors: 45
# K-Nearest Neighbour Accuracy Score: 0.98925364573
# K-Nearest Neighbour F-Measure: 0.975282868047
# K-Nearest Neighbour Sensitivity: 0.994687227559
# K-Nearest Neighbour Precision: 0.956842017997
# K-Nearest Neighbour Area Under ROC Curve: 0.991248331118
# K-Nearest Neighbour MCC: 0.968806075653
#
# n_neighbors: 50
# K-Nearest Neighbour Accuracy Score: 0.988102014252
# K-Nearest Neighbour F-Measure: 0.972419935277
# K-Nearest Neighbour Sensitivity: 0.990057281805
# K-Nearest Neighbour Precision: 0.955594520679
# K-Nearest Neighbour Area Under ROC Curve: 0.98881645202
# K-Nearest Neighbour MCC: 0.965160103153
#
# n_neighbors: 55
# K-Nearest Neighbour Accuracy Score: 0.987142321354
# K-Nearest Neighbour F-Measure: 0.97027662255
# K-Nearest Neighbour Sensitivity: 0.989113885579
# K-Nearest Neighbour Precision: 0.952339691112
# K-Nearest Neighbour Area Under ROC Curve: 0.98785298485
# K-Nearest Neighbour MCC: 0.962435350863
#
# n_neighbors: 60
# K-Nearest Neighbour Accuracy Score: 0.986566873313
# K-Nearest Neighbour F-Measure: 0.96895098229
# K-Nearest Neighbour Sensitivity: 0.987341753532
# K-Nearest Neighbour Precision: 0.951373432273
# K-Nearest Neighbour Area Under ROC Curve: 0.986844967607
# K-Nearest Neighbour MCC: 0.960705601467
#
# n_neighbors: 65
# K-Nearest Neighbour Accuracy Score: 0.986566873313
# K-Nearest Neighbour F-Measure: 0.96895098229
# K-Nearest Neighbour Sensitivity: 0.987341753532
# K-Nearest Neighbour Precision: 0.951373432273
# K-Nearest Neighbour Area Under ROC Curve: 0.986844967607
# K-Nearest Neighbour MCC: 0.960705601467
#
# n_neighbors: 70
# K-Nearest Neighbour Accuracy Score: 0.985799118995
# K-Nearest Neighbour F-Measure: 0.967148504049
# K-Nearest Neighbour Sensitivity: 0.98554365645
# K-Nearest Neighbour Precision: 0.949604619137
# K-Nearest Neighbour Area Under ROC Curve: 0.985705512224
# K-Nearest Neighbour MCC: 0.958429903945
#
# n_neighbors: 75
# K-Nearest Neighbour Accuracy Score: 0.985799118995
# K-Nearest Neighbour F-Measure: 0.967148504049
# K-Nearest Neighbour Sensitivity: 0.98554365645
# K-Nearest Neighbour Precision: 0.949604619137
# K-Nearest Neighbour Area Under ROC Curve: 0.985705512224
# K-Nearest Neighbour MCC: 0.958429903945
#
# n_neighbors: 80
# K-Nearest Neighbour Accuracy Score: 0.985799118995
# K-Nearest Neighbour F-Measure: 0.967148504049
# K-Nearest Neighbour Sensitivity: 0.98554365645
# K-Nearest Neighbour Precision: 0.949604619137
# K-Nearest Neighbour Area Under ROC Curve: 0.985705512224
# K-Nearest Neighbour MCC: 0.958429903945
#
# n_neighbors: 85
# K-Nearest Neighbour Accuracy Score: 0.985607180415
# K-Nearest Neighbour F-Measure: 0.96675101451
# K-Nearest Neighbour Sensitivity: 0.98554365645
# K-Nearest Neighbour Precision: 0.948844923016
# K-Nearest Neighbour Area Under ROC Curve: 0.985581749848
# K-Nearest Neighbour MCC: 0.957921142952
#
# n_neighbors: 90
# K-Nearest Neighbour Accuracy Score: 0.985415241835
# K-Nearest Neighbour F-Measure: 0.966356823638
# K-Nearest Neighbour Sensitivity: 0.98554365645
# K-Nearest Neighbour Precision: 0.948097480057
# K-Nearest Neighbour Area Under ROC Curve: 0.985457987472
# K-Nearest Neighbour MCC: 0.957417873793
#
# n_neighbors: 95
# K-Nearest Neighbour Accuracy Score: 0.985223303256
# K-Nearest Neighbour F-Measure: 0.965916634357
# K-Nearest Neighbour Sensitivity: 0.984681587485
# K-Nearest Neighbour Precision: 0.948068507147
# K-Nearest Neighbour Area Under ROC Curve: 0.985026952989
# K-Nearest Neighbour MCC: 0.956850538451
#
# n_neighbors: 100
# K-Nearest Neighbour Accuracy Score: 0.985223303256
# K-Nearest Neighbour F-Measure: 0.965916634357
# K-Nearest Neighbour Sensitivity: 0.984681587485
# K-Nearest Neighbour Precision: 0.948068507147
# K-Nearest Neighbour Area Under ROC Curve: 0.985026952989
# K-Nearest Neighbour MCC: 0.956850538451
#
#
# Optimum Accuracy for K-Nearest Neighbour: 0.993859436245
# Optimum Parameters:
# n_neighbors=1
# n_estimators: 5
# Random Forest Accuracy Score: 0.993284355903
# Random Forest F-Measure: 0.984286310347
# Random Forest Sensitivity: 0.984735928671
# Random Forest Precision: 0.980957332488
# Random Forest Area Under ROC Curve: 0.990702463966
# Random Forest MCC: 0.983145614001
#
# n_estimators: 10
# Random Forest Accuracy Score: 0.993092049625
# Random Forest F-Measure: 0.984701692438
# Random Forest Sensitivity: 0.986484672198
# Random Forest Precision: 0.983341805075
# Random Forest Area Under ROC Curve: 0.990925160314
# Random Forest MCC: 0.981350312282
#
# n_estimators: 25
# Random Forest Accuracy Score: 0.993475926784
# Random Forest F-Measure: 0.984656600798
# Random Forest Sensitivity: 0.985472594653
# Random Forest Precision: 0.980844529628
# Random Forest Area Under ROC Curve: 0.990895719647
# Random Forest MCC: 0.980087399592
#
# n_estimators: 50
# Random Forest Accuracy Score: 0.993284355903
# Random Forest F-Measure: 0.985225799934
# Random Forest Sensitivity: 0.986434133115
# Random Forest Precision: 0.984310520027
# Random Forest Area Under ROC Curve: 0.989616251118
# Random Forest MCC: 0.97969251343
#
# n_estimators: 75
# Random Forest Accuracy Score: 0.993283988204
# Random Forest F-Measure: 0.984820975419
# Random Forest Sensitivity: 0.986434133115
# Random Forest Precision: 0.983359800668
# Random Forest Area Under ROC Curve: 0.990646321996
# Random Forest MCC: 0.97962033955
#
# n_estimators: 100
# Random Forest Accuracy Score: 0.993476294482
# Random Forest F-Measure: 0.984390815952
# Random Forest Sensitivity: 0.987288833969
# Random Forest Precision: 0.982533358167
# Random Forest Area Under ROC Curve: 0.991197434799
# Random Forest MCC: 0.978533335684
#
# n_estimators: 150
# Random Forest Accuracy Score: 0.993475926784
# Random Forest F-Measure: 0.98481740925
# Random Forest Sensitivity: 0.988150902935
# Random Forest Precision: 0.98254201168
# Random Forest Area Under ROC Curve: 0.990646321996
# Random Forest MCC: 0.980189069098
#
# n_estimators: 200
# Random Forest Accuracy Score: 0.993092417323
# Random Forest F-Measure: 0.98439908974
# Random Forest Sensitivity: 0.986434133115
# Random Forest Precision: 0.98254201168
# Random Forest Area Under ROC Curve: 0.990770084372
# Random Forest MCC: 0.979029663637
#
# n_estimators: 250
# Random Forest Accuracy Score: 0.993284355903
# Random Forest F-Measure: 0.983966236947
# Random Forest Sensitivity: 0.987288833969
# Random Forest Precision: 0.98254201168
# Random Forest Area Under ROC Curve: 0.990770084372
# Random Forest MCC: 0.981304421888
#
# n_estimators: 300
# Random Forest Accuracy Score: 0.993284355903
# Random Forest F-Measure: 0.98481740925
# Random Forest Sensitivity: 0.986434133115
# Random Forest Precision: 0.982533358167
# Random Forest Area Under ROC Curve: 0.990770084372
# Random Forest MCC: 0.980743713938
#
# n_estimators: 350
# Random Forest Accuracy Score: 0.993284355903
# Random Forest F-Measure: 0.984384556456
# Random Forest Sensitivity: 0.986434133115
# Random Forest Precision: 0.982549379791
# Random Forest Area Under ROC Curve: 0.990770084372
# Random Forest MCC: 0.980743713938
#
# n_estimators: 400
# Random Forest Accuracy Score: 0.993284355903
# Random Forest F-Measure: 0.98439908974
# Random Forest Sensitivity: 0.986434133115
# Random Forest Precision: 0.982549379791
# Random Forest Area Under ROC Curve: 0.990770084372
# Random Forest MCC: 0.980743713938
#
# n_estimators: 450
# Random Forest Accuracy Score: 0.993284355903
# Random Forest F-Measure: 0.984384556456
# Random Forest Sensitivity: 0.986434133115
# Random Forest Precision: 0.982549379791
# Random Forest Area Under ROC Curve: 0.990646321996
# Random Forest MCC: 0.980189069098
#
# n_estimators: 500
# Random Forest Accuracy Score: 0.993284355903
# Random Forest F-Measure: 0.984384556456
# Random Forest Sensitivity: 0.987288833969
# Random Forest Precision: 0.982549379791
# Random Forest Area Under ROC Curve: 0.990770084372
# Random Forest MCC: 0.980189069098
#
#
# Optimum Accuracy for Random Forest: 0.993476294482
# Optimum Parameters:
# n_estimators=100

# %% [markdown]
# ### 8. Implement a stacking ensemble, which combines the best performing classifiers obtained in step 7 by a meta-learner (which can be logistic regression). Here you will use the optimum hyper-parameters you found in step 7 to train the models you selected in stacking. You can try different combinations of classifiers for this purpose. Perform cross-validation and report the same accuracy measures as in step 5. Then train the model on the train set 2 and test on validation set. Report the accuracy measures on validation data.
